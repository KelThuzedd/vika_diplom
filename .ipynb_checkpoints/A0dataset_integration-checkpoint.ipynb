# %%
import pandas as pd
import numpy as np

# # Чтение данных об арбитражных делах
# data_dela = pd.read_excel('data/СПАРК_Выборка_арбитражных_дел_20231014_2307.xlsx', skiprows=3)
# # Convert 'data_dela' DataFrame to Parquet format
# data_dela.drop('№', axis=1, inplace=True)
# 
# data_dela.to_parquet('data/data_dela.parquet', index=False)

# Read the Parquet file back into a DataFrame
data_dela = pd.read_parquet('data/data_dela.parquet')

# Заполнение пропущенных значений в столбце 'Дата иска' методом forward fill
data_dela['Дата иска'] = data_dela['Дата иска'].fillna(method='ffill')

# # Чтение данных о компаниях за разные года
# data_2008 = pd.read_excel('data/СПАРК_Выборка_компаний_20231021_2232.xlsx', skiprows=3)
# data_2013 = pd.read_excel('data/СПАРК_Выборка_компаний_20231021_2234.xlsx', skiprows=3)
# data_2019 = pd.read_excel('data/СПАРК_Выборка_компаний_20231021_2230.xlsx', skiprows=3)
# 
# data_2008 = data_2008.drop('№', axis=1)
# data_2013 = data_2013.drop('№', axis=1)
# data_2019 = data_2019.drop('№', axis=1)
# 
# # Сохранение данных о компаниях за разные года в формате Parquet
# data_2008.to_parquet('data/data_2008.parquet', index=False)
# data_2013.to_parquet('data/data_2013.parquet', index=False)
# data_2019.to_parquet('data/data_2019.parquet', index=False)


# Чтение данных из файлов Parquet
data_2008 = pd.read_parquet('data/data_2008.parquet')
data_2013 = pd.read_parquet('data/data_2013.parquet')
data_2019 = pd.read_parquet('data/data_2019.parquet')

# %%
# Обновление столбца 'Дата' в данных о компаниях на основе данных об арбитражных делах
for index, row in data_dela.iterrows():
    value_to_match = row['Ответчик']
    matching_row = data_2008[data_2008['Наименование'] == value_to_match]

    if not matching_row.empty:
        matching_index = matching_row.index[0]
        data_2008.at[matching_index, 'Дата иска'] = row['Дата иска']

# %%
col  = ['Наименование', 'Регистрационный номер', 'Адрес (место нахождения)',
        'Код налогоплательщика', 'Регион регистрации',
        'Вид деятельности/отрасль', 'ИФР', 'ИПД', 'Важная информация',
        'Мои списки',]
# Объединение данных по столбцам "Наименование" и "Регистрационный номер"
merged_data = pd.merge(data_2008, data_2013, on=col, how='inner')
merged_data = pd.merge(merged_data, data_2019, on=col, how='inner')
merged_data
# В результате получится объединенный DataFrame с дополнительными столбцами для каждого года
# Out:
#                 Наименование  Регистрационный номер  \
# 0             100РА ЛТД, ООО           1.135038e+12
# 1              1015 УСМР, АО           1.027739e+12
# 2               162-КЖИ, ООО           1.143668e+12
# 3     1МСМУ СТАЛЬМОНТАЖ, ООО           1.077760e+12
# 4               201 УНР, ООО           1.157746e+12
# ...                      ...                    ...
# 9116                    None                    NaN
# 9117                    None                    NaN
# 9118                    None                    NaN
# 9119                    None                    NaN
# 9120                    None                    NaN
#
#                                Адрес (место нахождения)  \
# 0     119121, г. Москва, вн.тер.г. муниципальный окр...
# 1     143003, Московская обл, Одинцово г, г.о. Одинц...
# 2     123308, г. Москва, вн.тер.г. муниципальный окр...
# 3     129329, г. Москва, вн.тер.г. муниципальный окр...
# 4     117630, г. Москва, вн.тер.г. муниципальный окр...
# ...                                                 ...
# 9116                                               None
# 9117                                               None
# 9118                                               None
# 9119                                               None
# 9120                                               None
#
#       Код налогоплательщика  Регион регистрации  \
# 0              5.038096e+09              Москва
# 1              7.734009e+09  Московская область
# 2              3.664135e+09              Москва
# 3              7.705809e+09              Москва
# 4              7.719093e+09              Москва
# ...                     ...                 ...
# 9116                    NaN                None
# 9117                    NaN                None
# 9118                    NaN                None
# 9119                    NaN                None
# 9120                    NaN                None
#
#                   Вид деятельности/отрасль   ИФР  ИПД  \
# 0     Строительство жилых и нежилых зданий  59.0  NaN
# 1     Строительство жилых и нежилых зданий  26.0  NaN
# 2     Строительство жилых и нежилых зданий  83.0  NaN
# 3     Строительство жилых и нежилых зданий  94.0  NaN
# 4     Строительство жилых и нежилых зданий  37.0  NaN
# ...                                    ...   ...  ...
# 9116                                  None   NaN  NaN
# 9117                                  None   NaN  NaN
# 9118                                  None   NaN  NaN
# 9119                                  None   NaN  NaN
# 9120                                  None   NaN  NaN
#
#                                       Важная информация Мои списки  ...  \
# 0                                                \n\n\n      "STR"  ...
# 1     \nЕсть заявление в суд о банкротстве (13.07.20...      "STR"  ...
# 2     Регистрирующим органом принято решение о предс...      "STR"  ...
# 3                                                \n\n\n      "STR"  ...
# 4                                                \n\n\n      "STR"  ...
# ...                                                 ...        ...  ...
# 9116                                               None       None  ...
# 9117                                               None       None  ...
# 9118                                               None       None  ...
# 9119                                               None       None  ...
# 9120                                               None       None  ...
#
#       2018, Коэффициент быстрой ликвидности, %  \
# 0                                       2.9346
# 1                                       0.9701
# 2                                       1.2777
# 3                                       1.0113
# 4                                       0.7878
# ...                                        ...
# 9116                                       NaN
# 9117                                       NaN
# 9118                                       NaN
# 9119                                       NaN
# 9120                                       NaN
#
#       2019, Коэффициент быстрой ликвидности, %  \
# 0                                       0.6877
# 1                                       0.9422
# 2                                       1.1624
# 3                                       1.0202
# 4                                       0.6167
# ...                                        ...
# 9116                                       NaN
# 9117                                       NaN
# 9118                                       NaN
# 9119                                       NaN
# 9120                                       NaN
#
#       2020, Коэффициент быстрой ликвидности, %  \
# 0                                       0.6952
# 1                                       1.0669
# 2                                       1.8047
# 3                                       0.9890
# 4                                       0.5593
# ...                                        ...
# 9116                                       NaN
# 9117                                       NaN
# 9118                                       NaN
# 9119                                       NaN
# 9120                                       NaN
#
#       2021, Коэффициент быстрой ликвидности, %  \
# 0                                       0.6034
# 1                                       1.0184
# 2                                      14.3377
# 3                                       0.8961
# 4                                       0.5710
# ...                                        ...
# 9116                                       NaN
# 9117                                       NaN
# 9118                                       NaN
# 9119                                       NaN
# 9120                                       NaN
#
#       2022, Коэффициент быстрой ликвидности, %  \
# 0                                       0.4631
# 1                                       0.9065
# 2                                          NaN
# 3                                       0.8951
# 4                                       0.9376
# ...                                        ...
# 9116                                       NaN
# 9117                                       NaN
# 9118                                       NaN
# 9119                                       NaN
# 9120                                       NaN
#
#       2018, Коэффициент абсолютной ликвидности, %  \
# 0                                          0.3779
# 1                                          0.0560
# 2                                          1.1154
# 3                                          0.1125
# 4                                          0.3181
# ...                                           ...
# 9116                                          NaN
# 9117                                          NaN
# 9118                                          NaN
# 9119                                          NaN
# 9120                                          NaN
#
#       2019, Коэффициент абсолютной ликвидности, %  \
# 0                                          0.1368
# 1                                          0.0307
# 2                                          0.2247
# 3                                          0.0502
# 4                                          0.0265
# ...                                           ...
# 9116                                          NaN
# 9117                                          NaN
# 9118                                          NaN
# 9119                                          NaN
# 9120                                          NaN
#
#       2020, Коэффициент абсолютной ликвидности, %  \
# 0                                          0.0400
# 1                                          0.0484
# 2                                          0.1754
# 3                                          0.0761
# 4                                          0.0392
# ...                                           ...
# 9116                                          NaN
# 9117                                          NaN
# 9118                                          NaN
# 9119                                          NaN
# 9120                                          NaN
#
#       2021, Коэффициент абсолютной ликвидности, %  \
# 0                                          0.0128
# 1                                          0.0199
# 2                                          0.0172
# 3                                          0.0124
# 4                                          0.0599
# ...                                           ...
# 9116                                          NaN
# 9117                                          NaN
# 9118                                          NaN
# 9119                                          NaN
# 9120                                          NaN
#
#       2022, Коэффициент абсолютной ликвидности, %
# 0                                          0.0024
# 1                                          0.0209
# 2                                             NaN
# 3                                          0.0123
# 4                                          0.3692
# ...                                           ...
# 9116                                          NaN
# 9117                                          NaN
# 9118                                          NaN
# 9119                                          NaN
# 9120                                          NaN
#
# [9121 rows x 446 columns]

# %%
# Удаление дубликатов по столбцу 'Наименование'
combined_data_unique = merged_data

# Добавление идентификаторов 'ID' к уникальным компаниям
combined_data_unique['ID'] = range(1, len(combined_data_unique) + 1)

# Выбор столбцов без цифр в названиях
columns_without_digits = combined_data_unique.filter(regex='^[^\d]*$')

# Выбор определенных столбцов
selected_columns = columns_without_digits.columns

# Транспонирование только выбранных столбцов
attribute_value_pairs = combined_data_unique.melt(id_vars=selected_columns, var_name='Атрибут', value_name='Значение')

# %%
# Разделение столбца 'Атрибут' на два столбца
split_values = attribute_value_pairs['Атрибут'].str.split(',', n=1, expand=True)
attribute_value_pairs['Год'] = split_values[0]
attribute_value_pairs['Атрибут2'] = split_values[1]

# Удаление исходного столбца 'Атрибут'
attribute_value_pairs.drop(['Атрибут', 'ID', 'ИПД', 'ИФР'], axis=1, inplace=True)

# Получение списка всех столбцов в DataFrame
all_columns = attribute_value_pairs.columns

# Исключение столбцов 'Атрибут2' и 'Значение' из списка
selected_columns = [col for col in all_columns if col not in ['Атрибут2', 'Значение']]

# Заполнение пропущенных значений в выбранных столбцах
attribute_value_pairs[selected_columns] = attribute_value_pairs[selected_columns].fillna('Заменить_значение_по_умолчанию')

# %%
# Применение pivot_table с использованием выбранных столбцов в качестве индекса
integrated_data = attribute_value_pairs.pivot_table(index=selected_columns, columns='Атрибут2', values='Значение').reset_index()

# Сброс имен индекса для улучшения читаемости
integrated_data.reset_index(inplace=True)

# Вывод результатов
integrated_data
# Out:
# Атрибут2  index    Наименование Регистрационный номер  \
# 0             0  100РА ЛТД, ООО       1135038000679.0
# 1             1  100РА ЛТД, ООО       1135038000679.0
# 2             2  100РА ЛТД, ООО       1135038000679.0
# 3             3  100РА ЛТД, ООО       1135038000679.0
# 4             4  100РА ЛТД, ООО       1135038000679.0
# ...         ...             ...                   ...
# 77276     77276        ЯСУ, ООО       1137604013172.0
# 77277     77277        ЯСУ, ООО       1137604013172.0
# 77278     77278        ЯСУ, ООО       1137604013172.0
# 77279     77279        ЯСУ, ООО       1137604013172.0
# 77280     77280        ЯСУ, ООО       1137604013172.0
#
# Атрибут2                           Адрес (место нахождения)  \
# 0         119121, г. Москва, вн.тер.г. муниципальный окр...
# 1         119121, г. Москва, вн.тер.г. муниципальный окр...
# 2         119121, г. Москва, вн.тер.г. муниципальный окр...
# 3         119121, г. Москва, вн.тер.г. муниципальный окр...
# 4         119121, г. Москва, вн.тер.г. муниципальный окр...
# ...                                                     ...
# 77276     150040, Ярославская обл, г.о. город Ярославль,...
# 77277     150040, Ярославская обл, г.о. город Ярославль,...
# 77278     150040, Ярославская обл, г.о. город Ярославль,...
# 77279     150040, Ярославская обл, г.о. город Ярославль,...
# 77280     150040, Ярославская обл, г.о. город Ярославль,...
#
# Атрибут2  Код налогоплательщика   Регион регистрации  \
# 0                  5.038096e+09               Москва
# 1                  5.038096e+09               Москва
# 2                  5.038096e+09               Москва
# 3                  5.038096e+09               Москва
# 4                  5.038096e+09               Москва
# ...                         ...                  ...
# 77276              7.604248e+09  Ярославская область
# 77277              7.604248e+09  Ярославская область
# 77278              7.604248e+09  Ярославская область
# 77279              7.604248e+09  Ярославская область
# 77280              7.604248e+09  Ярославская область
#
# Атрибут2              Вид деятельности/отрасль Важная информация Мои списки  \
# 0         Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 1         Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 2         Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 3         Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 4         Строительство жилых и нежилых зданий            \n\n\n      "STR"
# ...                                        ...               ...        ...
# 77276     Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 77277     Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 77278     Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 77279     Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 77280     Строительство жилых и нежилых зданий            \n\n\n      "STR"
#
# Атрибут2                       Дата иска  ...  \
# 0         Заменить_значение_по_умолчанию  ...
# 1         Заменить_значение_по_умолчанию  ...
# 2         Заменить_значение_по_умолчанию  ...
# 3         Заменить_значение_по_умолчанию  ...
# 4         Заменить_значение_по_умолчанию  ...
# ...                                  ...  ...
# 77276     Заменить_значение_по_умолчанию  ...
# 77277     Заменить_значение_по_умолчанию  ...
# 77278     Заменить_значение_по_умолчанию  ...
# 77279     Заменить_значение_по_умолчанию  ...
# 77280     Заменить_значение_по_умолчанию  ...
#
# Атрибут2  Период погашения кредиторской задолженности, дни  \
# 0                                                    48.21
# 1                                                    93.43
# 2                                                   144.05
# 3                                                    29.73
# 4                                                   173.59
# ...                                                    ...
# 77276                                               270.34
# 77277                                               180.63
# 77278                                                75.47
# 77279                                                68.78
# 77280                                               221.62
#
# Атрибут2   Рентабельность активов (ROA), %   Рентабельность затрат, %  \
# 0                                   0.7014                     0.1629
# 1                                  -0.2829                     0.0225
# 2                                   0.0308                     0.0483
# 3                                   0.5661                     0.0843
# 4                                   0.0248                     0.0130
# ...                                    ...                        ...
# 77276                               0.0062                    -0.0667
# 77277                               0.0122                     0.0174
# 77278                               0.0045                     0.0037
# 77279                               0.0355                    -0.0295
# 77280                               0.0034                     0.0578
#
# Атрибут2   Рентабельность капитала (ROE), %   Рентабельность продаж, %  \
# 0                                    2.4167                     0.1401
# 1                                   -1.0439                     0.0220
# 2                                    0.2192                     0.0460
# 3                                    1.7658                     0.0777
# 4                                    0.0744                     0.0129
# ...                                     ...                        ...
# 77276                                0.5051                    -0.0715
# 77277                                1.3191                     0.0171
# 77278                                0.8367                     0.0037
# 77279                                1.1948                    -0.0304
# 77280                                0.1109                     0.0546
#
# Атрибут2   Себестоимость продаж, RUB   Собственный оборотный капитал, RUB  \
# 0                          2775000.0                             342000.0
# 1                          2096000.0                              98000.0
# 2                          1699000.0                             121000.0
# 3                         26989000.0                            1954000.0
# 4                          8440000.0                            2205000.0
# ...                              ...                                  ...
# 77276                    538535000.0                         -106245000.0
# 77277                    475278000.0                          -26689000.0
# 77278                    572141000.0                           24473000.0
# 77279                    275635000.0                           25007000.0
# 77280                    186114000.0                           28238000.0
#
# Атрибут2   Соотношение совокупного долга к EBIT, %  \
# 0                                           0.0796
# 1                                              NaN
# 2                                           0.0000
# 3                                           0.0000
# 4                                           0.5291
# ...                                            ...
# 77276                                          NaN
# 77277                                          NaN
# 77278                                       1.8116
# 77279                                       0.1550
# 77280                                       4.2358
#
# Атрибут2   Соотношение совокупного долга к капиталу, %  \
# 0                                               0.0962
# 1                                               0.0000
# 2                                               0.0000
# 3                                               0.0000
# 4                                               0.0475
# ...                                                ...
# 77276                                              NaN
# 77277                                              NaN
# 77278                                           7.4906
# 77279                                           0.1913
# 77280                                           1.4632
#
# Атрибут2   Соотношение чистого долга к капиталу, %
# 0                                          -0.1538
# 1                                          -0.2653
# 2                                          -3.1488
# 3                                          -0.1464
# 4                                          -0.0542
# ...                                            ...
# 77276                                      -5.6802
# 77277                                     -56.7717
# 77278                                       2.7856
# 77279                                      -4.5800
# 77280                                      -7.1061
#
# [77281 rows x 40 columns]

# %%
# Save the original_data_filtered DataFrame to an Excel file
integrated_data.to_excel('data/integrated_data.xlsx', index=False)
# Save the original_data_filtered DataFrame to a Parquet file
integrated_data['Регистрационный номер'] = integrated_data['Регистрационный номер'].replace('Заменить_значение_по_умолчанию', 0)
integrated_data['Дата иска'] = integrated_data['Дата иска'].replace('Заменить_значение_по_умолчанию', 0)
# Convert 'Дата иска' column to datetime64 data type
integrated_data['Дата иска'] = pd.to_datetime(integrated_data['Дата иска'])
integrated_data.to_parquet('data/integrated_data.parquet', index=False)
