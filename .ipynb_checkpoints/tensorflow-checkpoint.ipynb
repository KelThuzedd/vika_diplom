# %%
import pandas as pd
from helper_functions import run_experiments
# Загружаем данные из формата parquet
X_train = pd.read_parquet('data/X_train.parquet')
X_test = pd.read_parquet('data/X_test.parquet')
y_train = pd.read_parquet('data/y_train.parquet')
y_test = pd.read_parquet('data/y_test.parquet')

# %%
output_activation='sigmoid'
loss_metric='binary_crossentropy'
monitor_metric='val_loss'
neurons_list = [[64,32,32]]
epochs = [5]
batch_size = [64]
validation_split = 0.1
optimizer = ['adam']
activation = ['relu']
l2 = 0.1
patience = 10
learning_rate=0
dropout = 0.1

# %%
new_results_df,model = run_experiments(neurons_list, X_train, y_train, X_test, y_test, epochs, batch_size, validation_split, optimizer, activation, l2, patience, learning_rate, dropout,output_activation,loss_metric,monitor_metric) # Сама функция нейросети
# Out:
# Epoch 1/5
#  9/14 [==================>...........] - ETA: 0s - loss: 84460064.0000 - accuracy: 0.4911 INFO:tensorflow:Assets written to: ../data/models\best_model_[64, 32, 32]_5_64_adam_relu_0_0.1\assets
# 14/14 [==============================] - 3s 121ms/step - loss: 71872320.0000 - accuracy: 0.4909 - val_loss: 49972044.0000 - val_accuracy: 0.4788
# Epoch 2/5
# 10/14 [====================>.........] - ETA: 0s - loss: 45044992.0000 - accuracy: 0.4712INFO:tensorflow:Assets written to: ../data/models\best_model_[64, 32, 32]_5_64_adam_relu_0_0.1\assets
# 14/14 [==============================] - 1s 102ms/step - loss: 37510504.0000 - accuracy: 0.4955 - val_loss: 10896326.0000 - val_accuracy: 0.4577
# Epoch 3/5
# 14/14 [==============================] - 0s 14ms/step - loss: 22081046.0000 - accuracy: 0.5011 - val_loss: 11095066.0000 - val_accuracy: 0.4603
# Epoch 4/5
# 10/14 [====================>.........] - ETA: 0s - loss: 22093522.0000 - accuracy: 0.5016INFO:tensorflow:Assets written to: ../data/models\best_model_[64, 32, 32]_5_64_adam_relu_0_0.1\assets
# 14/14 [==============================] - 1s 97ms/step - loss: 22956280.0000 - accuracy: 0.4955 - val_loss: 10393238.0000 - val_accuracy: 0.5079
# Epoch 5/5
#  8/14 [================>.............] - ETA: 0s - loss: 15329014.0000 - accuracy: 0.4759INFO:tensorflow:Assets written to: ../data/models\best_model_[64, 32, 32]_5_64_adam_relu_0_0.1\assets
# 14/14 [==============================] - 1s 93ms/step - loss: 13412313.0000 - accuracy: 0.5125 - val_loss: 5800492.5000 - val_accuracy: 0.5582
# 6/6 [==============================] - 0s 4ms/step
# Accuracy on validation data: 0.5582010582010583
# Precision on validation data: 0.5518867924528302
# Recall on validation data: 0.6190476190476191
# F1 Score on validation data: 0.5835411471321696

# %%
results_all = pd.read_csv('data/models/results_all.csv')
results_all
# Out:
#    [64, 32, 32]  3  10107106.0  3404044.25  adam  relu  5  64  0.1  \
# 0  [64, 32, 32]  3  22956280.0  10393238.0  adam  relu  5  64  0.1
#
#    0.5264550264550265       0.5  0.8435754189944135  0.6278586278586279  0.1.1
# 0            0.558201  0.551887            0.619048            0.583541    0.1

# %%
# # Make predictions for all the data
all_data_predictions = model.predict(X_train)

# Create a new DataFrame to store the actual and predicted values
# Create a new DataFrame to store the actual and predicted values
# Create a new DataFrame to store the actual and predicted values
predictions_df = pd.DataFrame({'Actual': y_train['Категориальная переменная'].values.flatten(), 'Predicted': all_data_predictions.flatten()})

# Print the DataFrame
predictions_df
# Out:
# 28/28 [==============================] - 0s 2ms/step
#      Actual  Predicted
# 0     False        1.0
# 1     False        1.0
# 2      True        1.0
# 3      True        1.0
# 4      True        0.0
# ..      ...        ...
# 877    True        1.0
# 878   False        1.0
# 879   False        0.0
# 880    True        0.0
# 881   False        0.0
#
# [882 rows x 2 columns]
