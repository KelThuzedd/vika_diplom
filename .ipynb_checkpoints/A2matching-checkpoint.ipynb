# %%
import pandas as pd

# Загружаем исходные данные из файла parquet
data_cleaned = pd.read_parquet('data/data_cleaned.parquet')
data_cleaned
# Out:
#        index    Наименование  Регистрационный номер  \
# 0          0  100РА ЛТД, ООО           1.135038e+12
# 1          1  100РА ЛТД, ООО           1.135038e+12
# 2          2  100РА ЛТД, ООО           1.135038e+12
# 3         12   1015 УСМР, АО           1.027739e+12
# 4         13   1015 УСМР, АО           1.027739e+12
# ...      ...             ...                    ...
# 39936  77274        ЯСУ, ООО           1.137604e+12
# 39937  77276        ЯСУ, ООО           1.137604e+12
# 39938  77277        ЯСУ, ООО           1.137604e+12
# 39939  77278        ЯСУ, ООО           1.137604e+12
# 39940  77279        ЯСУ, ООО           1.137604e+12
#
#                                 Адрес (место нахождения)  \
# 0      119121, г. Москва, вн.тер.г. муниципальный окр...
# 1      119121, г. Москва, вн.тер.г. муниципальный окр...
# 2      119121, г. Москва, вн.тер.г. муниципальный окр...
# 3      143003, Московская обл, Одинцово г, г.о. Одинц...
# 4      143003, Московская обл, Одинцово г, г.о. Одинц...
# ...                                                  ...
# 39936  150040, Ярославская обл, г.о. город Ярославль,...
# 39937  150040, Ярославская обл, г.о. город Ярославль,...
# 39938  150040, Ярославская обл, г.о. город Ярославль,...
# 39939  150040, Ярославская обл, г.о. город Ярославль,...
# 39940  150040, Ярославская обл, г.о. город Ярославль,...
#
#        Код налогоплательщика   Регион регистрации  \
# 0               5.038096e+09               Москва
# 1               5.038096e+09               Москва
# 2               5.038096e+09               Москва
# 3               7.734009e+09   Московская область
# 4               7.734009e+09   Московская область
# ...                      ...                  ...
# 39936           7.604248e+09  Ярославская область
# 39937           7.604248e+09  Ярославская область
# 39938           7.604248e+09  Ярославская область
# 39939           7.604248e+09  Ярославская область
# 39940           7.604248e+09  Ярославская область
#
#                    Вид деятельности/отрасль  \
# 0      Строительство жилых и нежилых зданий
# 1      Строительство жилых и нежилых зданий
# 2      Строительство жилых и нежилых зданий
# 3      Строительство жилых и нежилых зданий
# 4      Строительство жилых и нежилых зданий
# ...                                     ...
# 39936  Строительство жилых и нежилых зданий
# 39937  Строительство жилых и нежилых зданий
# 39938  Строительство жилых и нежилых зданий
# 39939  Строительство жилых и нежилых зданий
# 39940  Строительство жилых и нежилых зданий
#
#                                        Важная информация Мои списки  \
# 0                                                 \n\n\n      "STR"
# 1                                                 \n\n\n      "STR"
# 2                                                 \n\n\n      "STR"
# 3      \nЕсть заявление в суд о банкротстве (13.07.20...      "STR"
# 4      \nЕсть заявление в суд о банкротстве (13.07.20...      "STR"
# ...                                                  ...        ...
# 39936                                             \n\n\n      "STR"
# 39937                                             \n\n\n      "STR"
# 39938                                             \n\n\n      "STR"
# 39939                                             \n\n\n      "STR"
# 39940                                             \n\n\n      "STR"
#
#        Дата иска  ...  Период погашения дебиторской задолженности, дни  \
# 0     1970-01-01  ...                                             49.0
# 1     1970-01-01  ...                                             93.0
# 2     1970-01-01  ...                                             80.0
# 3     2017-01-24  ...                                             55.0
# 4     2017-01-24  ...                                            116.0
# ...          ...  ...                                              ...
# 39936 1970-01-01  ...                                            275.0
# 39937 1970-01-01  ...                                             99.0
# 39938 1970-01-01  ...                                             82.0
# 39939 1970-01-01  ...                                             51.0
# 39940 1970-01-01  ...                                             78.0
#
#         Период погашения кредиторской задолженности, дни  \
# 0                                                  48.21
# 1                                                  93.43
# 2                                                 144.05
# 3                                                 187.56
# 4                                                 167.69
# ...                                                  ...
# 39936                                             747.46
# 39937                                             270.34
# 39938                                             180.63
# 39939                                              75.47
# 39940                                              68.78
#
#         Рентабельность активов (ROA), %   Рентабельность затрат, %  \
# 0                                0.7014                     0.1629
# 1                               -0.2829                     0.0225
# 2                                0.0308                     0.0483
# 3                                0.0024                     0.0081
# 4                                0.0077                     0.0051
# ...                                 ...                        ...
# 39936                            0.0006                     0.0355
# 39937                            0.0062                    -0.0667
# 39938                            0.0122                     0.0174
# 39939                            0.0045                     0.0037
# 39940                            0.0355                    -0.0295
#
#         Рентабельность капитала (ROE), %   Рентабельность продаж, %  \
# 0                                 2.4167                     0.1401
# 1                                -1.0439                     0.0220
# 2                                 0.2192                     0.0460
# 3                                 0.1218                     0.0081
# 4                                 0.3329                     0.0051
# ...                                  ...                        ...
# 39936                             0.0175                     0.0342
# 39937                             0.5051                    -0.0715
# 39938                             1.3191                     0.0171
# 39939                             0.8367                     0.0037
# 39940                             1.1948                    -0.0304
#
#         Себестоимость продаж, RUB   Собственный оборотный капитал, RUB  \
# 0                    2.775000e+06                             342000.0
# 1                    2.096000e+06                              98000.0
# 2                    1.699000e+06                             121000.0
# 3                    1.527064e+09                          -30908000.0
# 4                    1.743699e+09                           24160000.0
# ...                           ...                                  ...
# 39936                7.856100e+07                         -153116000.0
# 39937                5.385350e+08                         -106245000.0
# 39938                4.752780e+08                          -26689000.0
# 39939                5.721410e+08                           24473000.0
# 39940                2.756350e+08                           25007000.0
#
#         Соотношение чистого долга к капиталу, %  Категориальная переменная
# 0                                       -0.1538                      False
# 1                                       -0.2653                      False
# 2                                       -3.1488                      False
# 3                                      -25.3893                       True
# 4                                       -1.6624                       True
# ...                                         ...                        ...
# 39936                                   -0.3956                      False
# 39937                                   -5.6802                      False
# 39938                                  -56.7717                      False
# 39939                                    2.7856                      False
# 39940                                   -4.5800                      False
#
# [39941 rows x 37 columns]

# %%
# Фильтруем данные по категориальной переменной
bankrupt_data = data_cleaned[data_cleaned['Категориальная переменная'] == True]
no_bankrupt_data = data_cleaned[data_cleaned['Категориальная переменная'] == False]

# Приводим столбец 'Год' в тип int для компаний
no_bankrupt_data['Год'] = no_bankrupt_data['Год'].astype(int)
bankrupt_data['Год'] = bankrupt_data['Год'].astype(int)

# %%
# Вычисляем год иска для компаний, которые банкроты
bankrupt_data['Год иска'] = bankrupt_data['Дата иска'].apply(lambda x: x.year - 2 if x.month > 3 else x.year - 1)

# Фильтруем банкроты по году
filtered_data = bankrupt_data[bankrupt_data['Год'] == bankrupt_data['Год иска']]
filtered_data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9888\919790913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bankrupt_data['Год иска'] = bankrupt_data['Дата иска'].apply(lambda x: x.year - 2 if x.month > 3 else x.year - 1)
#        index             Наименование  Регистрационный номер  \
# 7         16            1015 УСМР, АО           1.027739e+12
# 43        80           2МЕН ГРУПП, АО           1.067746e+12
# 77       130              54, ООО ПМК           1.020203e+12
# 101      172        А КОНСТРАКШН, ООО           1.147847e+12
# 130      237           А.С.СТРОЙ, ООО           1.074706e+12
# ...      ...                      ...                    ...
# 39839  77085              ЮТА, ООО СК           1.138617e+12
# 39876  77150                 ЯИК, ООО           1.125027e+12
# 39908  77225  ЯНТАРЬСЕРВИСБАЛТИК, ООО           1.103925e+12
# 39917  77236           ЯРАВТОДОР, ООО           1.147602e+12
# 39928  77249                ЯРДА, ООО           1.186658e+12
#
#                                 Адрес (место нахождения)  \
# 7      143003, Московская обл, Одинцово г, г.о. Одинц...
# 43     625002, Тюменская обл., г. Тюмень, ул. Комсомо...
# 77     450032, Башкортостан Респ, г.о. город Уфа, г У...
# 101    197183, г. Санкт-Петербург, вн.тер.г. муниципа...
# 130    187330, Ленинградская обл, м.р-н Кировский, г....
# ...                                                  ...
# 39839  628452, Ханты-Мансийский Автономный Округ - Юг...
# 39876  140011, Московская обл., г. Люберцы, ул. Авиат...
# 39908  , Калининградская обл, г.о. город Калининград,...
# 39917  150506, Ярославская обл., Ярославский район, п...
# 39928  620062, Свердловская обл., г. Екатеринбург, ул...
#
#        Код налогоплательщика         Регион регистрации  \
# 7               7.734009e+09         Московская область
# 43              7.701651e+09          Тюменская область
# 77              2.770551e+08  Башкортостан (Республика)
# 101             7.814608e+09            Санкт-Петербург
# 130             4.706027e+09      Ленинградская область
# ...                      ...                        ...
# 39839           8.617031e+09          Тюменская область
# 39876           5.027184e+09         Московская область
# 39908           3.906221e+09    Калининградская область
# 39917           7.602111e+09        Ярославская область
# 39928           6.670471e+09       Свердловская область
#
#                    Вид деятельности/отрасль  \
# 7      Строительство жилых и нежилых зданий
# 43     Строительство жилых и нежилых зданий
# 77     Строительство жилых и нежилых зданий
# 101    Строительство жилых и нежилых зданий
# 130    Строительство жилых и нежилых зданий
# ...                                     ...
# 39839  Строительство жилых и нежилых зданий
# 39876  Строительство жилых и нежилых зданий
# 39908  Строительство жилых и нежилых зданий
# 39917  Строительство жилых и нежилых зданий
# 39928  Строительство жилых и нежилых зданий
#
#                                        Важная информация Мои списки  \
# 7      \nЕсть заявление в суд о банкротстве (13.07.20...      "STR"
# 43     \nЕсть заявление в суд о банкротстве (03.08.20...      "STR"
# 77                                                \n\n\n      "STR"
# 101    \nЕсть заявление в суд о банкротстве (04.02.20...      "STR"
# 130    \n\nНа 09.10.2023 17:02 есть решения ФНС о при...      "STR"
# ...                                                  ...        ...
# 39839                                             \n\n\n      "STR"
# 39876  Юридическое лицо признано несостоятельным (бан...      "STR"
# 39908                                             \n\n\n      "STR"
# 39917  \nСообщение о признаках банкротства (17.10.202...      "STR"
# 39928  \nЕсть заявление в суд о банкротстве (23.08.20...      "STR"
#
#        Дата иска  ...   Период погашения кредиторской задолженности, дни  \
# 7     2017-01-24  ...                                             297.01
# 43    2019-10-21  ...                                            3057.84
# 77    2020-10-14  ...                                              60.47
# 101   2020-10-26  ...                                              69.21
# 130   2017-08-07  ...                                             313.88
# ...          ...  ...                                                ...
# 39839 2021-05-17  ...                                             311.34
# 39876 2021-06-01  ...                                             148.01
# 39908 2017-02-07  ...                                             200.09
# 39917 2020-11-02  ...                                             724.22
# 39928 2021-08-09  ...                                             146.07
#
#         Рентабельность активов (ROA), %   Рентабельность затрат, %  \
# 7                                0.0015                     0.0021
# 43                               0.0005                     0.3097
# 77                               0.0671                     0.0246
# 101                              0.0053                     0.0003
# 130                              0.0302                     0.0462
# ...                                 ...                        ...
# 39839                            0.0021                     0.0174
# 39876                            0.0767                     0.0446
# 39908                            0.0031                     0.0035
# 39917                            0.0051                     0.0627
# 39928                           -0.0775                    -0.0189
#
#         Рентабельность капитала (ROE), %   Рентабельность продаж, %  \
# 7                                 0.0982                     0.0021
# 43                                0.0151                     0.2365
# 77                                0.2030                     0.0240
# 101                               0.7384                     0.0003
# 130                               0.1355                     0.0442
# ...                                  ...                        ...
# 39839                             0.0810                     0.0171
# 39876                             0.9803                     0.0427
# 39908                             0.3385                     0.0035
# 39917                             0.1696                     0.0590
# 39928                             0.2972                    -0.0193
#
#         Себестоимость продаж, RUB   Собственный оборотный капитал, RUB  \
# 7                    2.345886e+09                         -202179000.0
# 43                   4.355200e+07                         -285582000.0
# 77                   5.619070e+08                           36015000.0
# 101                  1.003772e+09                            5603000.0
# 130                  2.914990e+08                           72999000.0
# ...                           ...                                  ...
# 39839                2.836360e+08                          -50660000.0
# 39876                1.413950e+08                           10373000.0
# 39908                3.444840e+08                          -64195000.0
# 39917                2.283190e+08                          -12804000.0
# 39928                1.497490e+08                          -16790000.0
#
#         Соотношение чистого долга к капиталу, %  Категориальная переменная  \
# 7                                       -2.8941                       True
# 43                                       7.7479                       True
# 77                                      -1.1194                       True
# 101                                      7.2602                       True
# 130                                     -0.3136                       True
# ...                                         ...                        ...
# 39839                                   -0.1145                       True
# 39876                                    0.3538                       True
# 39908                                    0.4734                       True
# 39917                                    1.4195                       True
# 39928                                    1.6877                       True
#
#        Год иска
# 7          2016
# 43         2017
# 77         2018
# 101        2018
# 130        2015
# ...         ...
# 39839      2019
# 39876      2019
# 39908      2016
# 39917      2018
# 39928      2019
#
# [734 rows x 38 columns]

# %%
# # Удаляем строки с отсутствующими значениями в данных
# filtered_data = filtered_data.dropna()
# no_bankrupt_data = no_bankrupt_data.dropna()

# Создаем dataframe с парами компаний
pairs = []
used_companies = set()

for index, row in filtered_data.iterrows():
    year = row['Год']
    assets = row[' Активы  всего, RUB']  # Предположим, что у вас есть столбец 'Активы всего, RUB'

    # Фильтруем данные не банкротов для текущего года
    candidates = no_bankrupt_data[(no_bankrupt_data['Год'] == year)]
    if not candidates.empty:
        # Находим ближайшую компанию по размеру активов
        nearest_index = (candidates[' Активы  всего, RUB'] - assets).abs().idxmin()
        nearest_company_name = no_bankrupt_data.loc[nearest_index, 'Наименование']
        # Проверяем, использовали ли уже компанию в предыдущих парах
        if nearest_company_name not in used_companies:
            # Расчитываем разницу в процентах между банкротной и ближайшей компаниями
            bankrupt_assets = filtered_data.at[index, ' Активы  всего, RUB']
            nearest_assets = no_bankrupt_data.at[nearest_index, ' Активы  всего, RUB']
            percent_difference = ((nearest_assets - bankrupt_assets) / bankrupt_assets) * 100

            # Создаем пару и добавляем в список
            pair = {
                'Банкротная компания ID': index,
                'Ближайшая компания ID': nearest_index,
                'Год': year,
                'Разница в %': percent_difference,
            }
            pairs.append(pair)

            # Добавляем компанию в использованные
            used_companies.add(nearest_company_name)

# Создаем dataframe из списка пар
pairs_df = pd.DataFrame(pairs)
pairs_df
# Out:
#      Банкротная компания ID  Ближайшая компания ID   Год  Разница в %
# 0                         7                  19809  2016     0.092112
# 1                        43                  21173  2017    -1.028048
# 2                        77                  22991  2018    -0.065555
# 3                       101                  20356  2018    -0.025952
# 4                       130                  26194  2015    -0.007693
# ..                      ...                    ...   ...          ...
# 643                   39763                  11998  2018    -0.289716
# 644                   39839                   3101  2019     0.043269
# 645                   39876                  11123  2019     0.002211
# 646                   39917                  17823  2018    -0.009404
# 647                   39928                   6493  2019    -0.116871
#
# [648 rows x 4 columns]

# %%
# Извлекаем строки из оригинальных датафреймов по индексам
bankrupt_companies = filtered_data.loc[pairs_df['Банкротная компания ID']]
nearest_companies = no_bankrupt_data.loc[pairs_df['Ближайшая компания ID']]

# Объединяем информацию из оригинальных датафреймов
matched_data = pd.concat([nearest_companies, bankrupt_companies])

# Удаляем все дубликаты по наименованию компании
matched_data = matched_data.drop_duplicates(subset='Наименование', keep=False)
matched_data
# Out:
#        index         Наименование  Регистрационный номер  \
# 19809  39123        ПЭТРУСКО, ООО           1.137746e+12
# 21173  41643  РОССТРОЙИНВЕСТ, ЗАО           1.037828e+12
# 22991  44832     СЕРВИССТРОЙ, ООО           1.178617e+12
# 20356  40177          РЕЛЬЕФ, ООО           1.127847e+12
# 26194  50733        СК-СТРОЙ, ООО           1.085405e+12
# ...      ...                  ...                    ...
# 39763  76909    ЮНИТЕЛ ГРУПП, ООО           5.067746e+12
# 39839  77085          ЮТА, ООО СК           1.138617e+12
# 39876  77150             ЯИК, ООО           1.125027e+12
# 39917  77236       ЯРАВТОДОР, ООО           1.147602e+12
# 39928  77249            ЯРДА, ООО           1.186658e+12
#
#                                 Адрес (место нахождения)  \
# 19809  119285, г. Москва, вн.тер.г. муниципальный окр...
# 21173  197198, г. Санкт-Петербург, проспект Добролюбо...
# 22991  628680, Ханты-Мансийский Автономный Округ - Юг...
# 20356  195299, г. Санкт-Петербург, проспект Гражданск...
# 26194  630132, Новосибирская обл, г.о. город Новосиби...
# ...                                                  ...
# 39763  108811, г. Москва, км. Киевское Шоссе 22-Й (П ...
# 39839  628452, Ханты-Мансийский Автономный Округ - Юг...
# 39876  140011, Московская обл., г. Люберцы, ул. Авиат...
# 39917  150506, Ярославская обл., Ярославский район, п...
# 39928  620062, Свердловская обл., г. Екатеринбург, ул...
#
#        Код налогоплательщика     Регион регистрации  \
# 19809           7.730683e+09                 Москва
# 21173           7.813161e+09        Санкт-Петербург
# 22991           8.605030e+09      Тюменская область
# 20356           7.804493e+09        Санкт-Петербург
# 26194           5.405375e+09  Новосибирская область
# ...                      ...                    ...
# 39763           7.727585e+09                 Москва
# 39839           8.617031e+09      Тюменская область
# 39876           5.027184e+09     Московская область
# 39917           7.602111e+09    Ярославская область
# 39928           6.670471e+09   Свердловская область
#
#                    Вид деятельности/отрасль  \
# 19809  Строительство жилых и нежилых зданий
# 21173  Строительство жилых и нежилых зданий
# 22991  Строительство жилых и нежилых зданий
# 20356  Строительство жилых и нежилых зданий
# 26194  Строительство жилых и нежилых зданий
# ...                                     ...
# 39763  Строительство жилых и нежилых зданий
# 39839  Строительство жилых и нежилых зданий
# 39876  Строительство жилых и нежилых зданий
# 39917  Строительство жилых и нежилых зданий
# 39928  Строительство жилых и нежилых зданий
#
#                                        Важная информация   Мои списки  \
# 19809                                             \n\n\n        "STR"
# 21173  Прекратило деятельность при слиянии (07.12.2022).        "STR"
# 22991                                             \n\n\n        "STR"
# 20356                                             \n\n\n        "STR"
# 26194                                             \n\n\n  "А1", "STR"
# ...                                                  ...          ...
# 39763                                             \n\n\n        "STR"
# 39839                                             \n\n\n        "STR"
# 39876  Юридическое лицо признано несостоятельным (бан...        "STR"
# 39917  \nСообщение о признаках банкротства (17.10.202...        "STR"
# 39928  \nЕсть заявление в суд о банкротстве (23.08.20...        "STR"
#
#        Дата иска  ...   Период погашения кредиторской задолженности, дни  \
# 19809 1970-01-01  ...                                             331.78
# 21173 1970-01-01  ...                                            1666.38
# 22991 1970-01-01  ...                                              53.83
# 20356 1970-01-01  ...                                             193.02
# 26194 1970-01-01  ...                                             145.50
# ...          ...  ...                                                ...
# 39763 2020-05-06  ...                                             387.56
# 39839 2021-05-17  ...                                             311.34
# 39876 2021-06-01  ...                                             148.01
# 39917 2020-11-02  ...                                             724.22
# 39928 2021-08-09  ...                                             146.07
#
#         Рентабельность активов (ROA), %   Рентабельность затрат, %  \
# 19809                            0.0344                     0.0103
# 21173                            0.0003                     0.1825
# 22991                           -0.0319                     0.0774
# 20356                            0.0203                     0.0331
# 26194                            0.0054                     0.0115
# ...                                 ...                        ...
# 39763                           -0.0037                    -0.0696
# 39839                            0.0021                     0.0174
# 39876                            0.0767                     0.0446
# 39917                            0.0051                     0.0627
# 39928                           -0.0775                    -0.0189
#
#         Рентабельность капитала (ROE), %   Рентабельность продаж, %  \
# 19809                             0.5142                     0.0102
# 21173                             0.0010                     0.1544
# 22991                            -0.1231                     0.0718
# 20356                             0.3863                     0.0320
# 26194                             0.0515                     0.0114
# ...                                  ...                        ...
# 39763                            -0.0236                    -0.0748
# 39839                             0.0810                     0.0171
# 39876                             0.9803                     0.0427
# 39917                             0.1696                     0.0590
# 39928                             0.2972                    -0.0193
#
#         Себестоимость продаж, RUB   Собственный оборотный капитал, RUB  \
# 19809                1.865839e+09                         -486123000.0
# 21173                7.775200e+07                          483423000.0
# 22991                3.503680e+08                            9225000.0
# 20356                6.456370e+08                          -55598000.0
# 26194                4.469230e+08                          -30233000.0
# ...                           ...                                  ...
# 39763                2.796640e+08                           23409000.0
# 39839                2.836360e+08                          -50660000.0
# 39876                1.413950e+08                           10373000.0
# 39917                2.283190e+08                          -12804000.0
# 39928                1.497490e+08                          -16790000.0
#
#         Соотношение чистого долга к капиталу, %  Категориальная переменная  \
# 19809                                    1.3290                      False
# 21173                                   -0.0163                      False
# 22991                                   -0.9022                      False
# 20356                                   -0.8969                      False
# 26194                                   -0.3223                      False
# ...                                         ...                        ...
# 39763                                    0.0183                       True
# 39839                                   -0.1145                       True
# 39876                                    0.3538                       True
# 39917                                    1.4195                       True
# 39928                                    1.6877                       True
#
#        Год иска
# 19809       NaN
# 21173       NaN
# 22991       NaN
# 20356       NaN
# 26194       NaN
# ...         ...
# 39763    2018.0
# 39839    2019.0
# 39876    2019.0
# 39917    2018.0
# 39928    2019.0
#
# [1260 rows x 38 columns]

# %%
# Save the matching_data DataFrame as a Parquet file
matched_data.to_parquet('data/matched_data.parquet')

# Save the matching_data DataFrame as an Excel file
matched_data.to_excel('data/matched_data.xlsx', index=False)
