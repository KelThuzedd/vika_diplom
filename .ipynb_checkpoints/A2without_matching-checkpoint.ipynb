# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# Загрузка исходных данных из файла parquet
data_cleaned = pd.read_parquet('data/data_cleaned.parquet')
data_cleaned['Год'] = pd.to_numeric(data_cleaned['Год'], errors='coerce')

columns_to_drop = [       
  ' Выручка, RUB',
' Краткосрочные обязательства, RUB', ' Кредиторская задолженность, RUB',
' Нераспределенная прибыль (непокрытый убыток), RUB',
' Себестоимость продаж, RUB', ' Собственный оборотный капитал, RUB',' Активы  всего, RUB'
]
data_cleaned = data_cleaned.drop(columns=columns_to_drop)


# Список столбцов, для которых нужно рассчитать изменения в процентах за последний год
columns_to_calculate = [' Cooтношение дебиторской задолженности к активам компании, %',
       ' Доля рабочего капитала в активах компании, %',
       ' Коэффициент абсолютной ликвидности, %',
       ' Коэффициент быстрой ликвидности, %',
       ' Коэффициент обеспеченности собственными оборотными средствами, %',
       ' Коэффициент оборачиваемости совокупных активов, %',
       ' Коэффициент соотношения заемных и собственных средств, %',
       ' Коэффициент текущей ликвидности, %',
       ' Период оборота активов, дни', ' Период оборота запасов, дни',
       ' Период оборота основных средств, дни',
       ' Период погашения дебиторской задолженности, дни',
       ' Период погашения кредиторской задолженности, дни',
       ' Рентабельность активов (ROA), %', ' Рентабельность затрат, %',
       ' Рентабельность капитала (ROE), %', ' Рентабельность продаж, %',
       ' Соотношение чистого долга к капиталу, %']

# Выбор последних двух годов для каждой компании
last_years_data = data_cleaned.groupby('Наименование').apply(lambda x: x.nlargest(2, 'Год')).reset_index(drop=True)

def calculate_percentage_change(df, columns, years):
    if len(df) < years:
        return pd.Series([float('NaN')] * len(columns), index=columns)
    changes = (df.iloc[years-1][columns] - df.iloc[0][columns]) / df.iloc[0][columns] * 100
    return changes

# Вычисление изменений в процентах за последние 2 и 3 года для указанных столбцов
last_2_years_changes = data_cleaned.groupby('Наименование').apply(calculate_percentage_change, columns=columns_to_calculate, years=2)
last_3_years_changes = data_cleaned.groupby('Наименование').apply(calculate_percentage_change, columns=columns_to_calculate, years=3)
last_4_years_changes = data_cleaned.groupby('Наименование').apply(calculate_percentage_change, columns=columns_to_calculate, years=4)

# Замена пропусков на нули
last_2_years_changes = last_2_years_changes.fillna(0)
last_3_years_changes = last_3_years_changes.fillna(0)
last_4_years_changes = last_4_years_changes.fillna(0)
# Переименование столбцов
last_2_years_changes.columns = [col + '_change_last_2_years' for col in last_2_years_changes.columns]
last_3_years_changes.columns = [col + '_change_last_3_years' for col in last_3_years_changes.columns]
last_4_years_changes.columns = [col + '_change_last_4_years' for col in last_4_years_changes.columns]


# Объединение информации об изменениях с исходным датафреймом
data_cleaned = pd.merge(data_cleaned, last_2_years_changes, on='Наименование', how='left')
data_cleaned = pd.merge(data_cleaned, last_3_years_changes, on='Наименование', how='left')
data_cleaned = pd.merge(data_cleaned, last_4_years_changes, on='Наименование', how='left')
# Вывод результата
data_cleaned
# Out:
#        index    Наименование  Регистрационный номер  \
# 0          0  100РА ЛТД, ООО           1.135038e+12
# 1          1  100РА ЛТД, ООО           1.135038e+12
# 2          2  100РА ЛТД, ООО           1.135038e+12
# 3         12   1015 УСМР, АО           1.027739e+12
# 4         13   1015 УСМР, АО           1.027739e+12
# ...      ...             ...                    ...
# 39936  77274        ЯСУ, ООО           1.137604e+12
# 39937  77276        ЯСУ, ООО           1.137604e+12
# 39938  77277        ЯСУ, ООО           1.137604e+12
# 39939  77278        ЯСУ, ООО           1.137604e+12
# 39940  77279        ЯСУ, ООО           1.137604e+12
#
#                                 Адрес (место нахождения)  \
# 0      119121, г. Москва, вн.тер.г. муниципальный окр...
# 1      119121, г. Москва, вн.тер.г. муниципальный окр...
# 2      119121, г. Москва, вн.тер.г. муниципальный окр...
# 3      143003, Московская обл, Одинцово г, г.о. Одинц...
# 4      143003, Московская обл, Одинцово г, г.о. Одинц...
# ...                                                  ...
# 39936  150040, Ярославская обл, г.о. город Ярославль,...
# 39937  150040, Ярославская обл, г.о. город Ярославль,...
# 39938  150040, Ярославская обл, г.о. город Ярославль,...
# 39939  150040, Ярославская обл, г.о. город Ярославль,...
# 39940  150040, Ярославская обл, г.о. город Ярославль,...
#
#        Код налогоплательщика   Регион регистрации  \
# 0               5.038096e+09               Москва
# 1               5.038096e+09               Москва
# 2               5.038096e+09               Москва
# 3               7.734009e+09   Московская область
# 4               7.734009e+09   Московская область
# ...                      ...                  ...
# 39936           7.604248e+09  Ярославская область
# 39937           7.604248e+09  Ярославская область
# 39938           7.604248e+09  Ярославская область
# 39939           7.604248e+09  Ярославская область
# 39940           7.604248e+09  Ярославская область
#
#                    Вид деятельности/отрасль  \
# 0      Строительство жилых и нежилых зданий
# 1      Строительство жилых и нежилых зданий
# 2      Строительство жилых и нежилых зданий
# 3      Строительство жилых и нежилых зданий
# 4      Строительство жилых и нежилых зданий
# ...                                     ...
# 39936  Строительство жилых и нежилых зданий
# 39937  Строительство жилых и нежилых зданий
# 39938  Строительство жилых и нежилых зданий
# 39939  Строительство жилых и нежилых зданий
# 39940  Строительство жилых и нежилых зданий
#
#                                        Важная информация Мои списки  \
# 0                                                 \n\n\n      "STR"
# 1                                                 \n\n\n      "STR"
# 2                                                 \n\n\n      "STR"
# 3      \nЕсть заявление в суд о банкротстве (13.07.20...      "STR"
# 4      \nЕсть заявление в суд о банкротстве (13.07.20...      "STR"
# ...                                                  ...        ...
# 39936                                             \n\n\n      "STR"
# 39937                                             \n\n\n      "STR"
# 39938                                             \n\n\n      "STR"
# 39939                                             \n\n\n      "STR"
# 39940                                             \n\n\n      "STR"
#
#        Дата иска  ...   Период оборота активов, дни_change_last_4_years  \
# 0     1970-01-01  ...                                          0.000000
# 1     1970-01-01  ...                                          0.000000
# 2     1970-01-01  ...                                          0.000000
# 3     2017-01-24  ...                                          7.526882
# 4     2017-01-24  ...                                          7.526882
# ...          ...  ...                                               ...
# 39936 1970-01-01  ...                                        169.000000
# 39937 1970-01-01  ...                                        169.000000
# 39938 1970-01-01  ...                                        169.000000
# 39939 1970-01-01  ...                                        169.000000
# 39940 1970-01-01  ...                                        169.000000
#
#         Период оборота запасов, дни_change_last_4_years  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                   0.0
# 3                                                 300.0
# 4                                                 300.0
# ...                                                 ...
# 39936                                           12300.0
# 39937                                           12300.0
# 39938                                           12300.0
# 39939                                           12300.0
# 39940                                           12300.0
#
#         Период оборота основных средств, дни_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                             500.000000
# 4                                             500.000000
# ...                                                  ...
# 39936                                         -87.899543
# 39937                                         -87.899543
# 39938                                         -87.899543
# 39939                                         -87.899543
# 39940                                         -87.899543
#
#         Период погашения дебиторской задолженности, дни_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                             129.090909
# 4                                             129.090909
# ...                                                  ...
# 39936                                         450.000000
# 39937                                         450.000000
# 39938                                         450.000000
# 39939                                         450.000000
# 39940                                         450.000000
#
#         Период погашения кредиторской задолженности, дни_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                              -1.338238
# 4                                              -1.338238
# ...                                                  ...
# 39936                                         169.021793
# 39937                                         169.021793
# 39938                                         169.021793
# 39939                                         169.021793
# 39940                                         169.021793
#
#         Рентабельность активов (ROA), %_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                             108.333333
# 4                                             108.333333
# ...                                                  ...
# 39936                                         -77.857143
# 39937                                         -77.857143
# 39938                                         -77.857143
# 39939                                         -77.857143
# 39940                                         -77.857143
#
#         Рентабельность затрат, %_change_last_4_years  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 3                                          -1.234568
# 4                                          -1.234568
# ...                                              ...
# 39936                                    -481.142857
# 39937                                    -481.142857
# 39938                                    -481.142857
# 39939                                    -481.142857
# 39940                                    -481.142857
#
#         Рентабельность капитала (ROE), %_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                             129.556650
# 4                                             129.556650
# ...                                                  ...
# 39936                                         -80.977667
# 39937                                         -80.977667
# 39938                                         -80.977667
# 39939                                         -80.977667
# 39940                                         -80.977667
#
#         Рентабельность продаж, %_change_last_4_years  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 3                                          -1.234568
# 4                                          -1.234568
# ...                                              ...
# 39936                                    -515.697674
# 39937                                    -515.697674
# 39938                                    -515.697674
# 39939                                    -515.697674
# 39940                                    -515.697674
#
#         Соотношение чистого долга к капиталу, %_change_last_4_years
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                             -85.682551
# 4                                             -85.682551
# ...                                                  ...
# 39936                                          92.627509
# 39937                                          92.627509
# 39938                                          92.627509
# 39939                                          92.627509
# 39940                                          92.627509
#
# [39941 rows x 84 columns]

# %%
# Фильтруем данные по категориальной переменной
bankrupt_data = data_cleaned[data_cleaned['Категориальная переменная'] == True]
no_bankrupt_data = data_cleaned[data_cleaned['Категориальная переменная'] == False]

# Приводим столбец 'Год' в тип int для компаний
no_bankrupt_data['Год'] = no_bankrupt_data['Год'].astype(int)
bankrupt_data['Год'] = bankrupt_data['Год'].astype(int)
no_bankrupt_data
# Out:
# /var/folders/d1/6kc60f1s4v90_zvxf3qld_480000gn/T/ipykernel_10996/3286317991.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_bankrupt_data['Год'] = no_bankrupt_data['Год'].astype(int)
# /var/folders/d1/6kc60f1s4v90_zvxf3qld_480000gn/T/ipykernel_10996/3286317991.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bankrupt_data['Год'] = bankrupt_data['Год'].astype(int)
#        index            Наименование  Регистрационный номер  \
# 0          0          100РА ЛТД, ООО           1.135038e+12
# 1          1          100РА ЛТД, ООО           1.135038e+12
# 2          2          100РА ЛТД, ООО           1.135038e+12
# 16        40  1МСМУ СТАЛЬМОНТАЖ, ООО           1.077760e+12
# 17        42  1МСМУ СТАЛЬМОНТАЖ, ООО           1.077760e+12
# ...      ...                     ...                    ...
# 39936  77274                ЯСУ, ООО           1.137604e+12
# 39937  77276                ЯСУ, ООО           1.137604e+12
# 39938  77277                ЯСУ, ООО           1.137604e+12
# 39939  77278                ЯСУ, ООО           1.137604e+12
# 39940  77279                ЯСУ, ООО           1.137604e+12
#
#                                 Адрес (место нахождения)  \
# 0      119121, г. Москва, вн.тер.г. муниципальный окр...
# 1      119121, г. Москва, вн.тер.г. муниципальный окр...
# 2      119121, г. Москва, вн.тер.г. муниципальный окр...
# 16     129329, г. Москва, вн.тер.г. муниципальный окр...
# 17     129329, г. Москва, вн.тер.г. муниципальный окр...
# ...                                                  ...
# 39936  150040, Ярославская обл, г.о. город Ярославль,...
# 39937  150040, Ярославская обл, г.о. город Ярославль,...
# 39938  150040, Ярославская обл, г.о. город Ярославль,...
# 39939  150040, Ярославская обл, г.о. город Ярославль,...
# 39940  150040, Ярославская обл, г.о. город Ярославль,...
#
#        Код налогоплательщика   Регион регистрации  \
# 0               5.038096e+09               Москва
# 1               5.038096e+09               Москва
# 2               5.038096e+09               Москва
# 16              7.705809e+09               Москва
# 17              7.705809e+09               Москва
# ...                      ...                  ...
# 39936           7.604248e+09  Ярославская область
# 39937           7.604248e+09  Ярославская область
# 39938           7.604248e+09  Ярославская область
# 39939           7.604248e+09  Ярославская область
# 39940           7.604248e+09  Ярославская область
#
#                    Вид деятельности/отрасль Важная информация Мои списки  \
# 0      Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 1      Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 2      Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 16     Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 17     Строительство жилых и нежилых зданий            \n\n\n      "STR"
# ...                                     ...               ...        ...
# 39936  Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 39937  Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 39938  Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 39939  Строительство жилых и нежилых зданий            \n\n\n      "STR"
# 39940  Строительство жилых и нежилых зданий            \n\n\n      "STR"
#
#        Дата иска  ...   Период оборота активов, дни_change_last_4_years  \
# 0     1970-01-01  ...                                               0.0
# 1     1970-01-01  ...                                               0.0
# 2     1970-01-01  ...                                               0.0
# 16    1970-01-01  ...                                               0.0
# 17    1970-01-01  ...                                               0.0
# ...          ...  ...                                               ...
# 39936 1970-01-01  ...                                             169.0
# 39937 1970-01-01  ...                                             169.0
# 39938 1970-01-01  ...                                             169.0
# 39939 1970-01-01  ...                                             169.0
# 39940 1970-01-01  ...                                             169.0
#
#         Период оборота запасов, дни_change_last_4_years  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                   0.0
# 16                                                  0.0
# 17                                                  0.0
# ...                                                 ...
# 39936                                           12300.0
# 39937                                           12300.0
# 39938                                           12300.0
# 39939                                           12300.0
# 39940                                           12300.0
#
#         Период оборота основных средств, дни_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 16                                              0.000000
# 17                                              0.000000
# ...                                                  ...
# 39936                                         -87.899543
# 39937                                         -87.899543
# 39938                                         -87.899543
# 39939                                         -87.899543
# 39940                                         -87.899543
#
#         Период погашения дебиторской задолженности, дни_change_last_4_years  \
# 0                                                    0.0
# 1                                                    0.0
# 2                                                    0.0
# 16                                                   0.0
# 17                                                   0.0
# ...                                                  ...
# 39936                                              450.0
# 39937                                              450.0
# 39938                                              450.0
# 39939                                              450.0
# 39940                                              450.0
#
#         Период погашения кредиторской задолженности, дни_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 16                                              0.000000
# 17                                              0.000000
# ...                                                  ...
# 39936                                         169.021793
# 39937                                         169.021793
# 39938                                         169.021793
# 39939                                         169.021793
# 39940                                         169.021793
#
#         Рентабельность активов (ROA), %_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 16                                              0.000000
# 17                                              0.000000
# ...                                                  ...
# 39936                                         -77.857143
# 39937                                         -77.857143
# 39938                                         -77.857143
# 39939                                         -77.857143
# 39940                                         -77.857143
#
#         Рентабельность затрат, %_change_last_4_years  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 16                                          0.000000
# 17                                          0.000000
# ...                                              ...
# 39936                                    -481.142857
# 39937                                    -481.142857
# 39938                                    -481.142857
# 39939                                    -481.142857
# 39940                                    -481.142857
#
#         Рентабельность капитала (ROE), %_change_last_4_years  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 16                                              0.000000
# 17                                              0.000000
# ...                                                  ...
# 39936                                         -80.977667
# 39937                                         -80.977667
# 39938                                         -80.977667
# 39939                                         -80.977667
# 39940                                         -80.977667
#
#         Рентабельность продаж, %_change_last_4_years  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 16                                          0.000000
# 17                                          0.000000
# ...                                              ...
# 39936                                    -515.697674
# 39937                                    -515.697674
# 39938                                    -515.697674
# 39939                                    -515.697674
# 39940                                    -515.697674
#
#         Соотношение чистого долга к капиталу, %_change_last_4_years
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 16                                              0.000000
# 17                                              0.000000
# ...                                                  ...
# 39936                                          92.627509
# 39937                                          92.627509
# 39938                                          92.627509
# 39939                                          92.627509
# 39940                                          92.627509
#
# [32454 rows x 84 columns]

# %%
# Вычисляем год иска для компаний, которые банкроты
bankrupt_data['Год иска'] = bankrupt_data['Дата иска'].apply(lambda x: x.year - 2 if x.month > 3 else x.year - 1)

# Фильтруем банкроты по году
filtered_data = bankrupt_data[bankrupt_data['Год'] == bankrupt_data['Год иска']]
filtered_data
# Out:
# /var/folders/d1/6kc60f1s4v90_zvxf3qld_480000gn/T/ipykernel_10996/467618231.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bankrupt_data['Год иска'] = bankrupt_data['Дата иска'].apply(lambda x: x.year - 2 if x.month > 3 else x.year - 1)
#        index             Наименование  Регистрационный номер  \
# 7         16            1015 УСМР, АО           1.027739e+12
# 43        80           2МЕН ГРУПП, АО           1.067746e+12
# 77       130              54, ООО ПМК           1.020203e+12
# 101      172        А КОНСТРАКШН, ООО           1.147847e+12
# 130      237           А.С.СТРОЙ, ООО           1.074706e+12
# ...      ...                      ...                    ...
# 39839  77085              ЮТА, ООО СК           1.138617e+12
# 39876  77150                 ЯИК, ООО           1.125027e+12
# 39908  77225  ЯНТАРЬСЕРВИСБАЛТИК, ООО           1.103925e+12
# 39917  77236           ЯРАВТОДОР, ООО           1.147602e+12
# 39928  77249                ЯРДА, ООО           1.186658e+12
#
#                                 Адрес (место нахождения)  \
# 7      143003, Московская обл, Одинцово г, г.о. Одинц...
# 43     625002, Тюменская обл., г. Тюмень, ул. Комсомо...
# 77     450032, Башкортостан Респ, г.о. город Уфа, г У...
# 101    197183, г. Санкт-Петербург, вн.тер.г. муниципа...
# 130    187330, Ленинградская обл, м.р-н Кировский, г....
# ...                                                  ...
# 39839  628452, Ханты-Мансийский Автономный Округ - Юг...
# 39876  140011, Московская обл., г. Люберцы, ул. Авиат...
# 39908  , Калининградская обл, г.о. город Калининград,...
# 39917  150506, Ярославская обл., Ярославский район, п...
# 39928  620062, Свердловская обл., г. Екатеринбург, ул...
#
#        Код налогоплательщика         Регион регистрации  \
# 7               7.734009e+09         Московская область
# 43              7.701651e+09          Тюменская область
# 77              2.770551e+08  Башкортостан (Республика)
# 101             7.814608e+09            Санкт-Петербург
# 130             4.706027e+09      Ленинградская область
# ...                      ...                        ...
# 39839           8.617031e+09          Тюменская область
# 39876           5.027184e+09         Московская область
# 39908           3.906221e+09    Калининградская область
# 39917           7.602111e+09        Ярославская область
# 39928           6.670471e+09       Свердловская область
#
#                    Вид деятельности/отрасль  \
# 7      Строительство жилых и нежилых зданий
# 43     Строительство жилых и нежилых зданий
# 77     Строительство жилых и нежилых зданий
# 101    Строительство жилых и нежилых зданий
# 130    Строительство жилых и нежилых зданий
# ...                                     ...
# 39839  Строительство жилых и нежилых зданий
# 39876  Строительство жилых и нежилых зданий
# 39908  Строительство жилых и нежилых зданий
# 39917  Строительство жилых и нежилых зданий
# 39928  Строительство жилых и нежилых зданий
#
#                                        Важная информация Мои списки  \
# 7      \nЕсть заявление в суд о банкротстве (13.07.20...      "STR"
# 43     \nЕсть заявление в суд о банкротстве (03.08.20...      "STR"
# 77                                                \n\n\n      "STR"
# 101    \nЕсть заявление в суд о банкротстве (04.02.20...      "STR"
# 130    \n\nНа 09.10.2023 17:02 есть решения ФНС о при...      "STR"
# ...                                                  ...        ...
# 39839                                             \n\n\n      "STR"
# 39876  Юридическое лицо признано несостоятельным (бан...      "STR"
# 39908                                             \n\n\n      "STR"
# 39917  \nСообщение о признаках банкротства (17.10.202...      "STR"
# 39928  \nЕсть заявление в суд о банкротстве (23.08.20...      "STR"
#
#        Дата иска  ...   Период оборота запасов, дни_change_last_4_years  \
# 7     2017-01-24  ...                                      3.000000e+02
# 43    2019-10-21  ...                                     -3.381087e+01
# 77    2020-10-14  ...                                      5.107527e+01
# 101   2020-10-26  ...                                               inf
# 130   2017-08-07  ...                                      1.024286e+04
# ...          ...  ...                                               ...
# 39839 2021-05-17  ...                                      2.341667e+03
# 39876 2021-06-01  ...                                      0.000000e+00
# 39908 2017-02-07  ...                                               inf
# 39917 2020-11-02  ...                                      1.035000e+04
# 39928 2021-08-09  ...                                      0.000000e+00
#
#         Период оборота основных средств, дни_change_last_4_years  \
# 7                                             500.000000
# 43                                           5063.636364
# 77                                             11.864407
# 101                                                  inf
# 130                                           133.333333
# ...                                                  ...
# 39839                                        4277.777778
# 39876                                           0.000000
# 39908                                        -100.000000
# 39917                                                inf
# 39928                                           0.000000
#
#         Период погашения дебиторской задолженности, дни_change_last_4_years  \
# 7                                             129.090909
# 43                                             38.550390
# 77                                            148.076923
# 101                                           -57.446809
# 130                                           771.428571
# ...                                                  ...
# 39839                                         -10.937500
# 39876                                           0.000000
# 39908                                          -3.349282
# 39917                                         325.000000
# 39928                                           0.000000
#
#         Период погашения кредиторской задолженности, дни_change_last_4_years  \
# 7                                              -1.338238
# 43                                            -52.154827
# 77                                             45.798529
# 101                                           -14.717310
# 130                                          3784.653465
# ...                                                  ...
# 39839                                          32.658859
# 39876                                           0.000000
# 39908                                          42.812284
# 39917                                         279.450906
# 39928                                           0.000000
#
#         Рентабельность активов (ROA), %_change_last_4_years  \
# 7                                             108.333333
# 43                                            -86.046512
# 77                                           -602.173913
# 101                                           -33.642578
# 130                                           -95.033712
# ...                                                  ...
# 39839                                         -85.321101
# 39876                                           0.000000
# 39908                                           8.108108
# 39917                                         -81.386861
# 39928                                           0.000000
#
#         Рентабельность затрат, %_change_last_4_years  \
# 7                                          -1.234568
# 43                                        -26.565875
# 77                                       1320.833333
# 101                                       -63.567251
# 130                                       -41.813602
# ...                                              ...
# 39839                                     -59.345794
# 39876                                       0.000000
# 39908                                    1000.000000
# 39917                                     182.432432
# 39928                                       0.000000
#
#         Рентабельность капитала (ROE), %_change_last_4_years  \
# 7                                             129.556650
# 43                                            -94.316731
# 77                                          -1173.043478
# 101                                            -2.357574
# 130                                           -83.772455
# ...                                                  ...
# 39839                                        -148.324022
# 39876                                           0.000000
# 39908                                         -17.906951
# 39917                                         -91.422647
# 39928                                           0.000000
#
#         Рентабельность продаж, %_change_last_4_years  \
# 7                                          -1.234568
# 43                                        -20.333220
# 77                                       1275.000000
# 101                                       -59.890486
# 130                                       -39.945652
# ...                                              ...
# 39839                                     -58.851675
# 39876                                       0.000000
# 39908                                     911.111111
# 39917                                     171.889401
# 39928                                       0.000000
#
#         Соотношение чистого долга к капиталу, %_change_last_4_years  Год иска
# 7                                             -85.682551                 2016
# 43                                             47.508942                 2017
# 77                                            -50.692690                 2018
# 101                                           -96.478914                 2018
# 130                                           307.802341                 2015
# ...                                                  ...                  ...
# 39839                                        -361.826885                 2019
# 39876                                           0.000000                 2019
# 39908                                        2550.000000                 2016
# 39917                                         -92.838115                 2018
# 39928                                           0.000000                 2019
#
# [734 rows x 85 columns]

# %%
# Сортировка данных по столбцам "наименование" и "год"
sorted_data = no_bankrupt_data.sort_values(by=['Наименование', 'Год'])

# Группировка данных по столбцу "наименование" и выбор последней строки из каждой группы
last_year_data = sorted_data.groupby('Наименование').tail(1)
last_year_data
# Out:
#        index               Наименование  Регистрационный номер  \
# 2          2             100РА ЛТД, ООО           1.135038e+12
# 18        43     1МСМУ СТАЛЬМОНТАЖ, ООО           1.077760e+12
# 26        53               201 УНР, ООО           1.157746e+12
# 37        70                    2М, ООО           1.147328e+12
# 49        91            31 КВАРТАЛ, ООО           1.175050e+12
# ...      ...                        ...                    ...
# 39901  77203  ЯМАЛСТРОЙМЕХАНИЗАЦИЯ, ООО           1.138903e+12
# 39905  77219      ЯНА РАЙНИСА ПЛЮС, ООО           1.167747e+12
# 39927  77247        ЯРД-ИНЖИНИРИНГ, ООО           1.167627e+12
# 39933  77259       ЯРОСЛАВСКИЙ ДСК, ООО           1.137602e+12
# 39940  77279                   ЯСУ, ООО           1.137604e+12
#
#                                 Адрес (место нахождения)  \
# 2      119121, г. Москва, вн.тер.г. муниципальный окр...
# 18     129329, г. Москва, вн.тер.г. муниципальный окр...
# 26     117630, г. Москва, вн.тер.г. муниципальный окр...
# 37     432072, Ульяновская обл, г.о. город Ульяновск,...
# 49     141204, Московская обл., г. Пушкино, проезд Пи...
# ...                                                  ...
# 39901  629757, Ямало-Ненецкий окр., Надымский район, ...
# 39905  115432, г. Москва, проспект Андропова, д. 18 к...
# 39927  150030, Ярославская обл., г. Ярославль, проспе...
# 39933  150044, Ярославская обл., г. Ярославль, ул. Пр...
# 39940  150040, Ярославская обл, г.о. город Ярославль,...
#
#        Код налогоплательщика   Регион регистрации  \
# 2               5.038096e+09               Москва
# 18              7.705809e+09               Москва
# 26              7.719093e+09               Москва
# 37              7.328078e+09  Ульяновская область
# 49              5.038126e+09   Московская область
# ...                      ...                  ...
# 39901           8.903033e+09    Тюменская область
# 39905           7.733295e+09               Москва
# 39927           7.604300e+09  Ярославская область
# 39933           7.602096e+09  Ярославская область
# 39940           7.604248e+09  Ярославская область
#
#                    Вид деятельности/отрасль  \
# 2      Строительство жилых и нежилых зданий
# 18     Строительство жилых и нежилых зданий
# 26     Строительство жилых и нежилых зданий
# 37     Строительство жилых и нежилых зданий
# 49     Строительство жилых и нежилых зданий
# ...                                     ...
# 39901  Строительство жилых и нежилых зданий
# 39905  Строительство жилых и нежилых зданий
# 39927  Строительство жилых и нежилых зданий
# 39933  Строительство жилых и нежилых зданий
# 39940  Строительство жилых и нежилых зданий
#
#                                        Важная информация Мои списки  \
# 2                                                 \n\n\n      "STR"
# 18                                                \n\n\n      "STR"
# 26                                                \n\n\n      "STR"
# 37     \n\nНа 16.08.2023 10:27 есть решения ФНС о при...      "STR"
# 49                                                \n\n\n      "STR"
# ...                                                  ...        ...
# 39901  Юридическое лицо признано несостоятельным (бан...      "STR"
# 39905  Прекратило деятельность при присоединении (09....      "STR"
# 39927                                             \n\n\n      "STR"
# 39933  Юридическое лицо признано несостоятельным (бан...      "STR"
# 39940                                             \n\n\n      "STR"
#
#        Дата иска  ...   Период оборота активов, дни_change_last_4_years  \
# 2     1970-01-01  ...                                          0.000000
# 18    1970-01-01  ...                                          0.000000
# 26    1970-01-01  ...                                         10.666667
# 37    1970-01-01  ...                                         55.737705
# 49    1970-01-01  ...                                         50.793651
# ...          ...  ...                                               ...
# 39901 1970-01-01  ...                                       4117.283951
# 39905 1970-01-01  ...                                        -69.997920
# 39927 1970-01-01  ...                                        410.126582
# 39933 1970-01-01  ...                                        -46.645367
# 39940 1970-01-01  ...                                        169.000000
#
#         Период оборота запасов, дни_change_last_4_years  \
# 2                                              0.000000
# 18                                             0.000000
# 26                                          1280.952381
# 37                                           -95.503212
# 49                                           160.396040
# ...                                                 ...
# 39901                                     141279.069767
# 39905                                        -77.890672
# 39927                                        363.194444
# 39933                                        925.000000
# 39940                                      12300.000000
#
#         Период оборота основных средств, дни_change_last_4_years  \
# 2                                               0.000000
# 18                                              0.000000
# 26                                                   inf
# 37                                                   inf
# 49                                           4900.000000
# ...                                                  ...
# 39901                                        1099.890830
# 39905                                         -92.307692
# 39927                                                inf
# 39933                                         -62.145390
# 39940                                         -87.899543
#
#         Период погашения дебиторской задолженности, дни_change_last_4_years  \
# 2                                               0.000000
# 18                                              0.000000
# 26                                            -23.664122
# 37                                            787.500000
# 49                                             -1.960784
# ...                                                  ...
# 39901                                        4089.855072
# 39905                                         -67.747164
# 39927                                         235.294118
# 39933                                         -62.845850
# 39940                                         450.000000
#
#         Период погашения кредиторской задолженности, дни_change_last_4_years  \
# 2                                               0.000000
# 18                                              0.000000
# 26                                             10.806220
# 37                                            672.330097
# 49                                             29.884608
# ...                                                  ...
# 39901                                        1820.987157
# 39905                                         418.521446
# 39927                                         446.001559
# 39933                                         -53.704582
# 39940                                         169.021793
#
#         Рентабельность активов (ROA), %_change_last_4_years  \
# 2                                               0.000000
# 18                                              0.000000
# 26                                            206.597222
# 37                                            634.010152
# 49                                            -20.201294
# ...                                                  ...
# 39901                                        -136.512209
# 39905                                         -78.461538
# 39927                                         -84.281945
# 39933                                        -212.765957
# 39940                                         -77.857143
#
#         Рентабельность затрат, %_change_last_4_years  \
# 2                                           0.000000
# 18                                          0.000000
# 26                                        261.306533
# 37                                        337.903226
# 49                                         43.902439
# ...                                              ...
# 39901                                    -214.237907
# 39905                                   -1027.187689
# 39927                                     -36.432161
# 39933                                     172.500000
# 39940                                    -481.142857
#
#         Рентабельность капитала (ROE), %_change_last_4_years  \
# 2                                               0.000000
# 18                                              0.000000
# 26                                            -29.304727
# 37                                              9.205451
# 49                                            -76.769725
# ...                                                  ...
# 39901                                        -300.824468
# 39905                                         -58.706468
# 39927                                         -83.372016
# 39933                                        -111.144578
# 39940                                         -80.977667
#
#         Рентабельность продаж, %_change_last_4_years  \
# 2                                           0.000000
# 18                                          0.000000
# 26                                        244.102564
# 37                                        322.131148
# 49                                         42.500000
# ...                                              ...
# 39901                                    -860.347870
# 39905                                    -252.208997
# 39927                                     -34.599729
# 39933                                     166.242038
# 39940                                    -515.697674
#
#         Соотношение чистого долга к капиталу, %_change_last_4_years
# 2                                               0.000000
# 18                                              0.000000
# 26                                            -57.403669
# 37                                            -98.144028
# 49                                            -80.222379
# ...                                                  ...
# 39901                                         -96.751075
# 39905                                         -71.676892
# 39927                                         -95.140187
# 39933                                        -340.390161
# 39940                                          92.627509
#
# [4780 rows x 84 columns]

# %%
no_matched_data = pd.concat([last_year_data, filtered_data], ignore_index=True)

no_matched_data.to_parquet('data/no_matched_data.parquet')

# Save the matching_data DataFrame as an Excel file
no_matched_data.to_excel('data/no_matched_data.xlsx', index=False)
no_matched_data
# Out:
#       index             Наименование  Регистрационный номер  \
# 0         2           100РА ЛТД, ООО           1.135038e+12
# 1        43   1МСМУ СТАЛЬМОНТАЖ, ООО           1.077760e+12
# 2        53             201 УНР, ООО           1.157746e+12
# 3        70                  2М, ООО           1.147328e+12
# 4        91          31 КВАРТАЛ, ООО           1.175050e+12
# ...     ...                      ...                    ...
# 5509  77085              ЮТА, ООО СК           1.138617e+12
# 5510  77150                 ЯИК, ООО           1.125027e+12
# 5511  77225  ЯНТАРЬСЕРВИСБАЛТИК, ООО           1.103925e+12
# 5512  77236           ЯРАВТОДОР, ООО           1.147602e+12
# 5513  77249                ЯРДА, ООО           1.186658e+12
#
#                                Адрес (место нахождения)  \
# 0     119121, г. Москва, вн.тер.г. муниципальный окр...
# 1     129329, г. Москва, вн.тер.г. муниципальный окр...
# 2     117630, г. Москва, вн.тер.г. муниципальный окр...
# 3     432072, Ульяновская обл, г.о. город Ульяновск,...
# 4     141204, Московская обл., г. Пушкино, проезд Пи...
# ...                                                 ...
# 5509  628452, Ханты-Мансийский Автономный Округ - Юг...
# 5510  140011, Московская обл., г. Люберцы, ул. Авиат...
# 5511  , Калининградская обл, г.о. город Калининград,...
# 5512  150506, Ярославская обл., Ярославский район, п...
# 5513  620062, Свердловская обл., г. Екатеринбург, ул...
#
#       Код налогоплательщика       Регион регистрации  \
# 0              5.038096e+09                   Москва
# 1              7.705809e+09                   Москва
# 2              7.719093e+09                   Москва
# 3              7.328078e+09      Ульяновская область
# 4              5.038126e+09       Московская область
# ...                     ...                      ...
# 5509           8.617031e+09        Тюменская область
# 5510           5.027184e+09       Московская область
# 5511           3.906221e+09  Калининградская область
# 5512           7.602111e+09      Ярославская область
# 5513           6.670471e+09     Свердловская область
#
#                   Вид деятельности/отрасль  \
# 0     Строительство жилых и нежилых зданий
# 1     Строительство жилых и нежилых зданий
# 2     Строительство жилых и нежилых зданий
# 3     Строительство жилых и нежилых зданий
# 4     Строительство жилых и нежилых зданий
# ...                                    ...
# 5509  Строительство жилых и нежилых зданий
# 5510  Строительство жилых и нежилых зданий
# 5511  Строительство жилых и нежилых зданий
# 5512  Строительство жилых и нежилых зданий
# 5513  Строительство жилых и нежилых зданий
#
#                                       Важная информация Мои списки  Дата иска  \
# 0                                                \n\n\n      "STR" 1970-01-01
# 1                                                \n\n\n      "STR" 1970-01-01
# 2                                                \n\n\n      "STR" 1970-01-01
# 3     \n\nНа 16.08.2023 10:27 есть решения ФНС о при...      "STR" 1970-01-01
# 4                                                \n\n\n      "STR" 1970-01-01
# ...                                                 ...        ...        ...
# 5509                                             \n\n\n      "STR" 2021-05-17
# 5510  Юридическое лицо признано несостоятельным (бан...      "STR" 2021-06-01
# 5511                                             \n\n\n      "STR" 2017-02-07
# 5512  \nСообщение о признаках банкротства (17.10.202...      "STR" 2020-11-02
# 5513  \nЕсть заявление в суд о банкротстве (23.08.20...      "STR" 2021-08-09
#
#       ...   Период оборота запасов, дни_change_last_4_years  \
# 0     ...                                      0.000000e+00
# 1     ...                                      0.000000e+00
# 2     ...                                      1.280952e+03
# 3     ...                                     -9.550321e+01
# 4     ...                                      1.603960e+02
# ...   ...                                               ...
# 5509  ...                                      2.341667e+03
# 5510  ...                                      0.000000e+00
# 5511  ...                                               inf
# 5512  ...                                      1.035000e+04
# 5513  ...                                      0.000000e+00
#
#        Период оборота основных средств, дни_change_last_4_years  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                                   inf
# 3                                                   inf
# 4                                           4900.000000
# ...                                                 ...
# 5509                                        4277.777778
# 5510                                           0.000000
# 5511                                        -100.000000
# 5512                                                inf
# 5513                                           0.000000
#
#        Период погашения дебиторской задолженности, дни_change_last_4_years  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                            -23.664122
# 3                                            787.500000
# 4                                             -1.960784
# ...                                                 ...
# 5509                                         -10.937500
# 5510                                           0.000000
# 5511                                          -3.349282
# 5512                                         325.000000
# 5513                                           0.000000
#
#        Период погашения кредиторской задолженности, дни_change_last_4_years  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                             10.806220
# 3                                            672.330097
# 4                                             29.884608
# ...                                                 ...
# 5509                                          32.658859
# 5510                                           0.000000
# 5511                                          42.812284
# 5512                                         279.450906
# 5513                                           0.000000
#
#        Рентабельность активов (ROA), %_change_last_4_years  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                            206.597222
# 3                                            634.010152
# 4                                            -20.201294
# ...                                                 ...
# 5509                                         -85.321101
# 5510                                           0.000000
# 5511                                           8.108108
# 5512                                         -81.386861
# 5513                                           0.000000
#
#        Рентабельность затрат, %_change_last_4_years  \
# 0                                          0.000000
# 1                                          0.000000
# 2                                        261.306533
# 3                                        337.903226
# 4                                         43.902439
# ...                                             ...
# 5509                                     -59.345794
# 5510                                       0.000000
# 5511                                    1000.000000
# 5512                                     182.432432
# 5513                                       0.000000
#
#        Рентабельность капитала (ROE), %_change_last_4_years  \
# 0                                              0.000000
# 1                                              0.000000
# 2                                            -29.304727
# 3                                              9.205451
# 4                                            -76.769725
# ...                                                 ...
# 5509                                        -148.324022
# 5510                                           0.000000
# 5511                                         -17.906951
# 5512                                         -91.422647
# 5513                                           0.000000
#
#        Рентабельность продаж, %_change_last_4_years  \
# 0                                          0.000000
# 1                                          0.000000
# 2                                        244.102564
# 3                                        322.131148
# 4                                         42.500000
# ...                                             ...
# 5509                                     -58.851675
# 5510                                       0.000000
# 5511                                     911.111111
# 5512                                     171.889401
# 5513                                       0.000000
#
#        Соотношение чистого долга к капиталу, %_change_last_4_years  Год иска
# 0                                              0.000000                  NaN
# 1                                              0.000000                  NaN
# 2                                            -57.403669                  NaN
# 3                                            -98.144028                  NaN
# 4                                            -80.222379                  NaN
# ...                                                 ...                  ...
# 5509                                        -361.826885               2019.0
# 5510                                           0.000000               2019.0
# 5511                                        2550.000000               2016.0
# 5512                                         -92.838115               2018.0
# 5513                                           0.000000               2019.0
#
# [5514 rows x 85 columns]

# %%
y = no_matched_data['Категориальная переменная']

X = no_matched_data.select_dtypes(exclude=['object'])

X = X.drop(columns=['index','Регистрационный номер','Код налогоплательщика','Категориальная переменная','Дата иска','Год иска'])
X.columns
# Out:
# Index(['Год', ' Cooтношение дебиторской задолженности к активам компании, %',
#        ' Доля рабочего капитала в активах компании, %',
#        ' Коэффициент абсолютной ликвидности, %',
#        ' Коэффициент быстрой ликвидности, %',
#        ' Коэффициент обеспеченности собственными оборотными средствами, %',
#        ' Коэффициент оборачиваемости совокупных активов, %',
#        ' Коэффициент соотношения заемных и собственных средств, %',
#        ' Коэффициент текущей ликвидности, %', ' Период оборота активов, дни',
#        ' Период оборота запасов, дни', ' Период оборота основных средств, дни',
#        ' Период погашения дебиторской задолженности, дни',
#        ' Период погашения кредиторской задолженности, дни',
#        ' Рентабельность активов (ROA), %', ' Рентабельность затрат, %',
#        ' Рентабельность капитала (ROE), %', ' Рентабельность продаж, %',
#        ' Соотношение чистого долга к капиталу, %',
#        ' Cooтношение дебиторской задолженности к активам компании, %_change_last_2_years',
#        ' Доля рабочего капитала в активах компании, %_change_last_2_years',
#        ' Коэффициент абсолютной ликвидности, %_change_last_2_years',
#        ' Коэффициент быстрой ликвидности, %_change_last_2_years',
#        ' Коэффициент обеспеченности собственными оборотными средствами, %_change_last_2_years',
#        ' Коэффициент оборачиваемости совокупных активов, %_change_last_2_years',
#        ' Коэффициент соотношения заемных и собственных средств, %_change_last_2_years',
#        ' Коэффициент текущей ликвидности, %_change_last_2_years',
#        ' Период оборота активов, дни_change_last_2_years',
#        ' Период оборота запасов, дни_change_last_2_years',
#        ' Период оборота основных средств, дни_change_last_2_years',
#        ' Период погашения дебиторской задолженности, дни_change_last_2_years',
#        ' Период погашения кредиторской задолженности, дни_change_last_2_years',
#        ' Рентабельность активов (ROA), %_change_last_2_years',
#        ' Рентабельность затрат, %_change_last_2_years',
#        ' Рентабельность капитала (ROE), %_change_last_2_years',
#        ' Рентабельность продаж, %_change_last_2_years',
#        ' Соотношение чистого долга к капиталу, %_change_last_2_years',
#        ' Cooтношение дебиторской задолженности к активам компании, %_change_last_3_years',
#        ' Доля рабочего капитала в активах компании, %_change_last_3_years',
#        ' Коэффициент абсолютной ликвидности, %_change_last_3_years',
#        ' Коэффициент быстрой ликвидности, %_change_last_3_years',
#        ' Коэффициент обеспеченности собственными оборотными средствами, %_change_last_3_years',
#        ' Коэффициент оборачиваемости совокупных активов, %_change_last_3_years',
#        ' Коэффициент соотношения заемных и собственных средств, %_change_last_3_years',
#        ' Коэффициент текущей ликвидности, %_change_last_3_years',
#        ' Период оборота активов, дни_change_last_3_years',
#        ' Период оборота запасов, дни_change_last_3_years',
#        ' Период оборота основных средств, дни_change_last_3_years',
#        ' Период погашения дебиторской задолженности, дни_change_last_3_years',
#        ' Период погашения кредиторской задолженности, дни_change_last_3_years',
#        ' Рентабельность активов (ROA), %_change_last_3_years',
#        ' Рентабельность затрат, %_change_last_3_years',
#        ' Рентабельность капитала (ROE), %_change_last_3_years',
#        ' Рентабельность продаж, %_change_last_3_years',
#        ' Соотношение чистого долга к капиталу, %_change_last_3_years',
#        ' Cooтношение дебиторской задолженности к активам компании, %_change_last_4_years',
#        ' Доля рабочего капитала в активах компании, %_change_last_4_years',
#        ' Коэффициент абсолютной ликвидности, %_change_last_4_years',
#        ' Коэффициент быстрой ликвидности, %_change_last_4_years',
#        ' Коэффициент обеспеченности собственными оборотными средствами, %_change_last_4_years',
#        ' Коэффициент оборачиваемости совокупных активов, %_change_last_4_years',
#        ' Коэффициент соотношения заемных и собственных средств, %_change_last_4_years',
#        ' Коэффициент текущей ликвидности, %_change_last_4_years',
#        ' Период оборота активов, дни_change_last_4_years',
#        ' Период оборота запасов, дни_change_last_4_years',
#        ' Период оборота основных средств, дни_change_last_4_years',
#        ' Период погашения дебиторской задолженности, дни_change_last_4_years',
#        ' Период погашения кредиторской задолженности, дни_change_last_4_years',
#        ' Рентабельность активов (ROA), %_change_last_4_years',
#        ' Рентабельность затрат, %_change_last_4_years',
#        ' Рентабельность капитала (ROE), %_change_last_4_years',
#        ' Рентабельность продаж, %_change_last_4_years',
#        ' Соотношение чистого долга к капиталу, %_change_last_4_years'],
#       dtype='object')

# %%
# Разделите данные на тренировочный и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Check for infinite or NaN values in X_train and replace them with a suitable value
X_train.replace([np.inf, -np.inf, np.nan], 0, inplace=True)

# Check for infinite or NaN values in X_test and replace them with a suitable value
X_test.replace([np.inf, -np.inf, np.nan], 0, inplace=True)
# Сохраняем данные в формате parquet
X_train.to_parquet('data/X_train.parquet', index=False)
X_test.to_parquet('data/X_test.parquet', index=False)
y_train.to_frame().to_parquet('data/y_train.parquet', index=False)
y_test.to_frame().to_parquet('data/y_test.parquet', index=False)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt

from matplotlib import pyplot as plt
import xgboost as xgb


xgb_params = {
    "max_depth": 4,
    "n_estimators": 1200,
    "learning_rate": 0.09479924808897194,
    "subsample": 1,
    "gamma": 0.4756674273309772,
    "min_child_weight": 0.23357425487768094,
    "max_delta_step": 0.7274545805862332,
    "colsample_bytree": 0.9893220571413148,
    "reg_alpha": 0.674401793402349,
    "reg_lambda": 0.4832264465328138,
    "scale_pos_weight": 1.1956253627044895
}

# Обучите модель XGBRegressor
xgb_regressor = xgb.XGBRegressor(**xgb_params)
xgb_regressor.fit(X_train, y_train)

# Сделайте предсказания на тестовом наборе
y_pred_xgb = xgb_regressor.predict(X_test)

# Вычислите метрики для XGBRegressor

print("Metrics for XGBoost:")
# Вычисление MAE
mae = mean_absolute_error(y_test, y_pred_xgb)
print(f"MAE: {mae}")

# Вычисление RMSE
rmse = sqrt(mean_squared_error(y_test, y_pred_xgb))
print(f"RMSE: {rmse}")

# Вычисление R^2
r2 = r2_score(y_test, y_pred_xgb)
print(f"R^2: {r2}")
# Plot feature importance
xgb.plot_importance(xgb_regressor, max_num_features=30)
plt.show()
# Out:
# Metrics for XGBoost:
# MAE: 0.14053547382354736
# RMSE: 0.25487154354747005
# R^2: 0.4364088772186775

# %% [markdown]
# Metrics for XGBoost:
# MAE: 0.16451877355575562
# RMSE: 0.27886662989853334
# R^2: 0.32529411316718126

# %%
# Вычислите метрики для XGBClassifier
from sklearn.metrics import classification_report

# Округлите каждый элемент массива y_pred_xgb
y_pred_rounded = [round(pred) for pred in y_pred_xgb]

# Вычислите метрики классификации
classification_metrics = classification_report(y_test, y_pred_rounded)

print("Metrics for XGBoost:")
print(classification_metrics)
# Out:
# Metrics for XGBoost:
#               precision    recall  f1-score   support
#
#        False       0.93      0.97      0.95      1435
#         True       0.76      0.51      0.61       220
#
#     accuracy                           0.91      1655
#    macro avg       0.84      0.74      0.78      1655
# weighted avg       0.91      0.91      0.91      1655
